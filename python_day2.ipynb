# %% [markdown]
# Markdown 은 코드가 아닌 글쓰는 곳입니다.

# %% [markdown]
# ## 제목 heading1

# %% [markdown]
# $e^{i\pi} + 1 = 0$
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$

# %% [markdown]
# | This | is   |
# |------|------|
# |   a  | table|

# %% [markdown]
# 브라우저에 따라서 유튜브 동영상

# %% [markdown]
# <iframe width="560" height="315" src="https://www.youtube.com/embed/HqA75IhHuGM" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ![2019-womens-world-cup-day-6-5696430367309824-law.gif](attachment:2019-womens-world-cup-day-6-5696430367309824-law.gif)

# %%
a = [1,2,3,4,5]
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a.append(6)
a
# Out:
# [1, 2, 3, 4, 5, 6, 6]

# %%
a.append(7)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6, 6, 7]

# %%
a.pop(5)
# Out:
# 6

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
x = 8984849
i =1
while(2**i < x):
    i+=1

i, 2**(i)
# Out:
# (24, 16777216)

# %%
b = {'age':20, 'city':'seoul'}

# %%
b['age'] += 10
b['age']
# Out:
# 30

# %%
b['part'] = '개발부'
b
# Out:
# {'age': 30, 'city': 'seoul', 'part': '개발부'}

# %%
del b['age']
b
# Out:
# {'city': 'seoul', 'part': '개발부'}

# %%
b.keys()
# Out:
# dict_keys(['city', 'part'])
